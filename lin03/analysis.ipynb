# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 100

from setup import EQUILIBRIA, PSINORM_VALUES, TIGRESS_DIR, DEFAULTS_DIR, VERSION
# %aimport analyze
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
scan_name = 'nzhypz2'
scans = {}
for eq in EQUILIBRIA:
    scans[eq] = {}
    for pn in PSINORM_VALUES:
        scan_dir = TIGRESS_DIR / eq / pn / scan_name
        assert scan_dir.exists()
        scans[eq][pn] = analyze.LinearScan(scan_dir)

# %%
for eq in ['eq21']:
    for pn in['pn50','pn60','pn70','pn80']:
        scans[eq][pn].plot_omega(logx=False, verbose=False)

# %%
scans['eq21']['pn70'].plot_mode(nz0=64, fields='apar')
# Out:
# Parameters file: /home/dsmith/gene/tigress/lin03/eq21/pn70/nzhypz2/scanfiles0000/parameters_0006
# Field file: /home/dsmith/gene/tigress/lin03/eq21/pn70/nzhypz2/scanfiles0000/field_0006
# Parameters file: /home/dsmith/gene/tigress/lin03/eq21/pn70/nzhypz2/scanfiles0000/parameters_0007
# Field file: /home/dsmith/gene/tigress/lin03/eq21/pn70/nzhypz2/scanfiles0000/field_0007
# Parameters file: /home/dsmith/gene/tigress/lin03/eq21/pn70/nzhypz2/scanfiles0000/parameters_0008
# Field file: /home/dsmith/gene/tigress/lin03/eq21/pn70/nzhypz2/scanfiles0000/field_0008
# Parameters file: /home/dsmith/gene/tigress/lin03/eq21/pn70/nzhypz2/scanfiles0000/parameters_0009
# Field file: /home/dsmith/gene/tigress/lin03/eq21/pn70/nzhypz2/scanfiles0000/field_0009
# Parameters file: /home/dsmith/gene/tigress/lin03/eq21/pn70/nzhypz2/scanfiles0000/parameters_0010
# Field file: /home/dsmith/gene/tigress/lin03/eq21/pn70/nzhypz2/scanfiles0000/field_0010

# %% [markdown]
# |  | eq21 | eq50 |
# | --- | --- | --- |
# | pn50 | nz0>=64, hyp_z>=20 | nz0>=32, hyp_z>=30 |
# | pn60 | nz0>=64, hyp_z>=30 | nz0>=32, hyp_z>=30 |
# | pn70 | nz0>=128, hyp_z>=60 | nz0>=32, hyp_z>=30 |
